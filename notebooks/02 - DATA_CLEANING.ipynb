# %%
import os
import pandas as pd

# %%
DATA_RAW_PATH = os.path.join('..','data','raw')
DATA_RAW_NAME = ['abono.csv', 'aposentados.csv']

# %%
df_abono = pd.read_csv(os.path.join(DATA_RAW_PATH, DATA_RAW_NAME[0]), sep=';')
df_aposentado = pd.read_csv(os.path.join(DATA_RAW_PATH, DATA_RAW_NAME[1]), sep=';')

# %%
df_abono.head()
# Out:
#                                                 NOME          CPF  \
# 0  CICERO JOAQUIM DOS SANTOS FILHO               ...  ***204574**
# 1  PAULO ELISIO DE FARIA                         ...  ***402121**
# 2  MARIA VANILDA DOS SANTOS                      ...  ***184061**
# 3  SONIA CANDIDA BATISTA                         ...  ***086171**
# 4  MARIA GRACI DA CONCEICAO MAXIMA               ...  ***803611**
#
#                           DSC_CARGO_EMPREGO  \
# 0  AUDITOR FISCAL FEDERAL AGROPECUARIO
# 1  AGENTE ADMINISTRATIVO
# 2  AGENTE ADMINISTRATIVO
# 3  CONTADOR
# 4  AGENTE DE PORTARIA
#
#                                  NV_ESCOLARIDADE  \
# 0  ENSINO SUPERIOR
# 1  ENSINO SUPERIOR
# 2  ENSINO MEDIO
# 3  ENSINO SUPERIOR
# 4  ENSINO MEDIO
#
#                            DN_ORGAO_ATUACAO UF_UPAG  \
# 0  MINIST.DA AGRICULTURA,PECUARIA E ABAST.       PE
# 1  MINIST.DA AGRICULTURA,PECUARIA E ABAST.       DF
# 2  MINIST.DA AGRICULTURA,PECUARIA E ABAST.       DF
# 3  MINIST.DA AGRICULTURA,PECUARIA E ABAST.       DF
# 4  MINIST.DA AGRICULTURA,PECUARIA E ABAST.       DF
#
#                   DN_UNIDADE_ORGANIZACIONAL UF_RESIDENCIA  \
# 0  SUP FED AGRIC PEC ABAST EST PERNAMBUCO              PE
# 1  COORD GERAL ADM DE PESSOAS                          DF
# 2  COORD GERAL ADM DE PESSOAS                          DF
# 3  COORD GERAL ADM DE PESSOAS                          DF
# 4  COORD GERAL ADM DE PESSOAS                          DF
#
#                 CIDADE_RESIDENCIA          SITUACAO_SVR  QT_ANOS_SVR_PUBLICOS  \
# 0  CARUARU                         ATIVO PERMANENTE                        43
# 1  BRASILIA                        ATIVO PERMANENTE                        41
# 2  BRASILIA                        ATIVO PERMANENTE                        41
# 3  BRASILIA                        ATIVO EM OUTRO ORGAO                    41
# 4  BRASILIA                        ATIVO EM OUTRO ORGAO                    41
#
#    QT_MESES_SVR_PUBLICOS  ANO-MES_INICIO_ABONO_PERMANE           VAL
# 0                      8                        200312       2241,38
# 1                      7                        201001        558,32
# 2                      6                        200904        550,73
# 3                      5                        200909       1070,10
# 4                      3                        200312        543,75

# %%
df_aposentado.head()
# Out:
#                                                 NOME          CPF  \
# 0  IVAN DAS GRACAS FERNANDES                     ...  ***557741**
# 1  JESUS ANANIAS BORGES                          ...  ***279221**
# 2  SANDRA REGINA ARABE                           ...  ***560976**
# 3  SANDRA MIRANDA DE SOUZA                       ...  ***304409**
# 4  ANTONIO CARLOS MOCELIM                        ...  ***366949**
#
#    MAT_SERVIDOR                                  NM_ORGAO SIGLA_ORGAO  \
# 0  130000001102  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA
# 1  130000004957  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA
# 2  130000006958  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA
# 3  130000010019  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA
# 4  130000014751  MINIST.DA AGRICULTURA,PECUARIA E ABAST.   MAPA
#
#    CD_ORGAO                                     CARGO CLASSE PADRAO  REF  \
# 0         0  AGENTE DE INSP SANIT IND PROD ORIGEM ANI      S    IV     0
# 1         0  AGENTE DE INSP SANIT IND PROD ORIGEM ANI      S    IV     0
# 2         0  AUDITOR FISCAL FEDERAL AGROPECUARIO           S    IV     0
# 3         0  DATILOGRAFO                                   S    III    0
# 4         0  AUDITOR FISCAL FEDERAL AGROPECUARIO           S    IV     0
#
#    NIVEL             TP_APOSENTADORIA  \
# 0      0  VOLUNTARIA
# 1      0  VOLUNTARIA
# 2      0  VOLUNTARIA
# 3      0  VOLUNTARIA
# 4      0  VOLUNTARIA
#
#                            FUND_INATIVIDADE  \
# 0  EC103 3Ì EC47 3Ì
# 1  EC103 3Ì EC47 3Ì
# 2  EC103 3Ì EC47 3Ì
# 3  EC103 3Ì EC47 3Ì
# 4  EC47 3Ì
#
#                                       NM_DIPLO_LEGAL  DT_PUBLI_DO_DL  \
# 0  PORT 005915/2019, CGAP PUB: DO 31DEZ2019      ...        31122019
# 1  PORT 000287/2019, SFA-GO PUB: DO 12DEZ2019    ...        12122019
# 2  PORT 005934/2019, SFA-MG PUB: DO 31DEZ2019    ...        31122019
# 3  PORT 005779/2019, SFA-PR PUB: DO 16DEZ2019    ...        16122019
# 4  PORT 000217/2019, SFA-PA PUB: DO 02DEZ2019    ...         1122019
#
#                                      OC_INGRESSO_SVP DT_OC_INGRESSO_SVP  \
# 0  ADMISSAO SEM CONCURSO PUBLICO                 ...            9051978
# 1  ADMISSAO SEM CONCURSO PUBLICO                 ...            1101975
# 2  DECISAO JUDICIAL                              ...           15121975
# 3  ADMISSAO SEM CONCURSO PUBLICO                 ...            3051983
# 4  ADMISSAO SEM CONCURSO PUBLICO                 ...            1031985
#
#   VL_RENDIMENTO_LIQUIDO
# 0              5.007,99
# 1              7.338,88
# 2             16.512,75
# 3              3.053,80
# 4             11.914,70
